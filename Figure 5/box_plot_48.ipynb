# %%
#imports Matplotlib library and assigns shorthand 'plt'
import matplotlib.pyplot as plt
#imports Seaborn library and assigns shorthand 'sns'
import seaborn as sns
#imports Plotly library and assigns shorthand 'px'
import plotly.express as px
import os
import numpy as np

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times\\'
error_list_2 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_2.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_interpo\\'
error_list_2_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_2_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_cubic\\'
error_list_2_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_2_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_bicubic\\'
error_list_2_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_2_bicubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times\\'
error_list_3 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_3.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_interpo\\'
error_list_3_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_3_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_cubic\\'
error_list_3_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_3_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_bicubic\\'
error_list_3_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_3_bicubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times\\'
error_list_4 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_4.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_interpo\\'
error_list_4_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_4_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_cubic\\'
error_list_4_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_4_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_bicubic\\'
error_list_4_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_4_bicubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times\\'
error_list_6 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_6.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_interpo\\'
error_list_6_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_6_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_cubic\\'
error_list_6_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_6_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_bicubic\\'
error_list_6_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_6_bicubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times\\'
error_list_8 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_8.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_interpo\\'
error_list_8_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_8_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_cubic\\'
error_list_8_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_8_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_bicubic\\'
error_list_8_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_8_bicubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times\\'
error_list_10 = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_10.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_interpo\\'
error_list_10_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_10_interpo.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_cubic\\'
error_list_10_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_10_cubic.append(diff_array[i][j])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_bicubic\\'
error_list_10_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    for i in range(diff_array.shape[0]):
        for j in range(diff_array.shape[1]):
            error_list_10_bicubic.append(diff_array[i][j])

# %%
error_list_2_all = []
error_list_2_all.append(error_list_2)
error_list_2_all.append(error_list_2_interpo)
error_list_2_all.append(error_list_2_cubic)
error_list_2_all.append(error_list_2_bicubic)
error_list_3_all = []
error_list_3_all.append(error_list_3)
error_list_3_all.append(error_list_3_interpo)
error_list_3_all.append(error_list_3_cubic)
error_list_3_all.append(error_list_3_bicubic)
error_list_4_all = []
error_list_4_all.append(error_list_4)
error_list_4_all.append(error_list_4_interpo)
error_list_4_all.append(error_list_4_cubic)
error_list_4_all.append(error_list_4_bicubic)
error_list_6_all = []
error_list_6_all.append(error_list_6)
error_list_6_all.append(error_list_6_interpo)
error_list_6_all.append(error_list_6_cubic)
error_list_6_all.append(error_list_6_bicubic)
error_list_8_all = []
error_list_8_all.append(error_list_8)
error_list_8_all.append(error_list_8_interpo)
error_list_8_all.append(error_list_8_cubic)
error_list_8_all.append(error_list_8_bicubic)
error_list_10_all = []
error_list_10_all.append(error_list_10)
error_list_10_all.append(error_list_10_interpo)
error_list_10_all.append(error_list_10_cubic)
error_list_10_all.append(error_list_10_bicubic)
error_list_all = []
error_list_all.append(error_list_2_all)
error_list_all.append(error_list_3_all)
error_list_all.append(error_list_4_all)
error_list_all.append(error_list_6_all)
error_list_all.append(error_list_8_all)
error_list_all.append(error_list_10_all)

# %%
from pylab import legend, setp, axes

# %%
def setBoxColors(bp):
    setp(bp['boxes'][0], color='black')
    bp['boxes'][0].set(facecolor = 'cyan')
    setp(bp['caps'][0], color='black')
    setp(bp['caps'][1], color='black')
    setp(bp['whiskers'][0], color='black')
    setp(bp['whiskers'][1], color='black')
    setp(bp['medians'][0], color='black')

    setp(bp['boxes'][1], color='black')
    bp['boxes'][1].set(facecolor = 'yellow')
    setp(bp['caps'][2], color='black')
    setp(bp['caps'][3], color='black')
    setp(bp['whiskers'][2], color='black')
    setp(bp['whiskers'][3], color='black')
    setp(bp['medians'][1], color='black')

    setp(bp['boxes'][2], color='black')
    bp['boxes'][2].set(facecolor = 'red')
    setp(bp['caps'][2], color='black')
    setp(bp['caps'][3], color='black')
    setp(bp['whiskers'][2], color='black')
    setp(bp['whiskers'][3], color='black')
    setp(bp['medians'][2], color='black')

    setp(bp['boxes'][3], color='black')
    bp['boxes'][3].set(facecolor = 'green')
    setp(bp['caps'][2], color='black')
    setp(bp['caps'][3], color='black')
    setp(bp['whiskers'][2], color='black')
    setp(bp['whiskers'][3], color='black')
    setp(bp['medians'][3], color='black')

# %%
bp = plt.boxplot(error_list_2_all, positions = [1, 2, 3, 4], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_3_all, positions = [6, 7, 8, 9], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_4_all, positions = [11, 12, 13, 14], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_6_all, positions = [17, 18, 19, 20], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_8_all, positions = [22, 23, 24, 25], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_10_all, positions = [27, 28, 29, 30], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
plt.title('Up-scaling Test with Seen and Unseen Ratios')
plt.xlabel('Up-scaling Ratio')
plt.ylabel('Relative Error')
ticks = ['x2', 'x3', 'x4', 'x6', 'x8', 'x10']
tick_positions = [2.5, 7.5, 12.5, 18.5, 23.5, 28.5]
plt.xticks(tick_positions, ticks)
plt.axvline(x = 15.5, color = 'grey', linestyle = '--')
plt.legend(loc = 'upper left', )
legend_colors = ['cyan', 'yellow', 'red', 'green']
legend_labels = ['NN-IQS', 'Bilinear', 'Cubic', 'Bicubic']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc = 'upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_transition\\'
error_list_2_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_2_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_transition_interpo\\'
error_list_2_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_2_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_transition_cubic\\'
error_list_2_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_2_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\2_times_transition_bicubic\\'
error_list_2_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_2_transition_bicubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_transition\\'
error_list_3_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_3_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_transition_interpo\\'
error_list_3_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_3_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_transition_cubic\\'
error_list_3_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_3_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\3_times_transition_bicubic\\'
error_list_3_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_3_transition_bicubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_transition\\'
error_list_4_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_4_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_transition_interpo\\'
error_list_4_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_4_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_transition_cubic\\'
error_list_4_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_4_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\4_times_transition_bicubic\\'
error_list_4_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_4_transition_bicubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_transition\\'
error_list_6_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_6_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_transition_interpo\\'
error_list_6_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_6_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_transition_cubic\\'
error_list_6_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_6_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\6_times_transition_bicubic\\'
error_list_6_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_6_transition_bicubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_transition\\'
error_list_8_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_8_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_transition_interpo\\'
error_list_8_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_8_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_transition_cubic\\'
error_list_8_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_8_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\8_times_transition_bicubic\\'
error_list_8_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_8_transition_bicubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_transition\\'
error_list_10_transition = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_10_transition.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_transition_interpo\\'
error_list_10_transition_interpo = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_10_transition_interpo.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_transition_cubic\\'
error_list_10_transition_cubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_10_transition_cubic.append(diff_list[i])

# %%
directory = 'C:\\Users\\robwa\\liif-main\\datasets\\Schwinger\\test\\diff_input48\\10_times_transition_bicubic\\'
error_list_10_transition_bicubic = []
for filename in os.listdir(directory):
    file = directory + filename
    diff_array = np.load(file)
    diff_list = diff_array.tolist()
    for i in range(len(diff_list)):
        error_list_10_transition_bicubic.append(diff_list[i])

# %%
error_list_2_all_transition = []
error_list_2_all_transition.append(error_list_2_transition)
error_list_2_all_transition.append(error_list_2_transition_interpo)
error_list_2_all_transition.append(error_list_2_transition_cubic)
error_list_2_all_transition.append(error_list_2_transition_bicubic)
error_list_3_all_transition = []
error_list_3_all_transition.append(error_list_3_transition)
error_list_3_all_transition.append(error_list_3_transition_interpo)
error_list_3_all_transition.append(error_list_3_transition_cubic)
error_list_3_all_transition.append(error_list_3_transition_bicubic)
error_list_4_all_transition = []
error_list_4_all_transition.append(error_list_4_transition)
error_list_4_all_transition.append(error_list_4_transition_interpo)
error_list_4_all_transition.append(error_list_4_transition_cubic)
error_list_4_all_transition.append(error_list_4_transition_bicubic)
error_list_6_all_transition = []
error_list_6_all_transition.append(error_list_6_transition)
error_list_6_all_transition.append(error_list_6_transition_interpo)
error_list_6_all_transition.append(error_list_6_transition_cubic)
error_list_6_all_transition.append(error_list_6_transition_bicubic)
error_list_8_all_transition = []
error_list_8_all_transition.append(error_list_8_transition)
error_list_8_all_transition.append(error_list_8_transition_interpo)
error_list_8_all_transition.append(error_list_8_transition_cubic)
error_list_8_all_transition.append(error_list_8_transition_bicubic)
error_list_10_all_transition = []
error_list_10_all_transition.append(error_list_10_transition)
error_list_10_all_transition.append(error_list_10_transition_interpo)
error_list_10_all_transition.append(error_list_10_transition_cubic)
error_list_10_all_transition.append(error_list_10_transition_bicubic)

# %%
bp = plt.boxplot(error_list_2_all_transition, positions = [1, 2, 3, 4], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_3_all_transition, positions = [6, 7, 8, 9], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_4_all_transition, positions = [11, 12, 13, 14], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_6_all_transition, positions = [17, 18, 19, 20], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_8_all_transition, positions = [22, 23, 24, 25], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
bp = plt.boxplot(error_list_10_all_transition, positions = [27, 28, 29, 30], sym='', patch_artist = True, widths = 0.6 )
setBoxColors(bp)
plt.title('Up-scaling Test with Seen and Unseen Ratios within Transition Region')
plt.xlabel('Up-scaling Ratio')
plt.ylabel('Relative Error')
ticks = ['x2', 'x3', 'x4', 'x6', 'x8', 'x10']
tick_positions = [2.5, 7.5, 12.5, 18.5, 23.5, 28.5]
plt.xticks(tick_positions, ticks)
plt.axvline(x = 15.5, color = 'grey', linestyle = '--')
plt.legend(loc = 'upper left', )
legend_colors = ['cyan', 'yellow', 'red', 'green']
legend_labels = ['NN-IQS', 'Bilinear', 'Cubic', 'Bicubic']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc = 'upper left')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
